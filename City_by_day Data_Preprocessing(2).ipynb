# %% [markdown]
# # ***City Wise Knn Imputation,AQI Calculation & Outlier Detection-Treatment***

# %% [markdown]
# ##Data Interpretation

# %%
import pandas as pd
import numpy as np
import os
from sklearn.impute import KNNImputer


def fun(dframe):
  lis = []
  for i in range(0, dframe.shape[1]):
      if(dframe.iloc[:,i].dtypes == 'object'):
        dframe.iloc[:,i] = pd.Categorical(dframe.iloc[:,i])
        dframe.iloc[:,i] = dframe.iloc[:,i].cat.codes 
        dframe.iloc[:,i] = dframe.iloc[:,i].astype('object')

        lis.append(dframe.columns[i])
  KNN = KNNImputer(n_neighbors=3)
  dframe = pd.DataFrame(KNN.fit_transform(dframe))
  return dframe

# %%
df = pd.read_csv('/content/cities_by_day.csv')
df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5          223
# PM10           230
# NO             220
# NO2            242
# NOx             32
# NH3            207
# CO              33
# SO2            221
# O3             223
# C6H6            32
# C7H8            32
# C8H10         1201
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %%
df
# Out:
#                 City        Date   PM2.5  ...  C8H10   AQI    AQI_Bucket
# 0          Ahmedabad  01-01-2015    0.00  ...   0.00   NaN           NaN
# 1          Ahmedabad  01-02-2015   66.00  ...   3.77   NaN           NaN
# 2          Ahmedabad  01-03-2015  132.00  ...   2.25   NaN           NaN
# 3          Ahmedabad  01-04-2015  150.00  ...   1.00   NaN           NaN
# 4          Ahmedabad  01-05-2015  156.00  ...   2.78   NaN           NaN
# ...              ...         ...     ...  ...    ...   ...           ...
# 29526  Visakhapatnam   6/27/2020   15.02  ...   0.73  41.0          Good
# 29527  Visakhapatnam   6/28/2020   24.38  ...   0.38  70.0  Satisfactory
# 29528  Visakhapatnam   6/29/2020   22.91  ...   0.00  68.0  Satisfactory
# 29529  Visakhapatnam   6/30/2020   16.64  ...   0.00  54.0  Satisfactory
# 29530  Visakhapatnam  07-01-2020   15.00  ...    NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %% [markdown]
# ## Ahmedabad Imputation

# %%
df_Ahm = df.groupby(df.City)
df_Ahm = df_Ahm.get_group('Ahmedabad')
df_Ahm = fun(df_Ahm)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Aizawl Imputation

# %%
df_Aiz = df.groupby(df.City)
df_Aiz = df_Aiz.get_group("Aizawl")
df_Aiz = fun(df_Aiz)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Amaravati Imputation

# %%
df_Ama = df.groupby(df.City)
df_Ama = df_Ama.get_group("Amaravati")
df_Ama = fun(df_Ama)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Amritsar Imputation

# %%
df_Amr = df.groupby(df.City)
df_Amr = df_Amr.get_group("Amaravati")
df_Amr = fun(df_Amr)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Bengaluru Imputation

# %%
df_Ben = df.groupby(df.City)
df_Ben = df_Ben.get_group("Bengaluru")
df_Ben = fun(df_Ben)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Bhopal Imputation

# %%
df_Bho = df.groupby(df.City)
df_Bho = df_Bho.get_group("Bhopal")
df_Bho = fun(df_Bho)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Brajrajnagar Imputation

# %%
df_Braj = df.groupby(df.City)
df_Braj = df_Braj.get_group("Brajrajnagar")
df_Braj = fun(df_Braj)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Chandigarh Imputation

# %%
df_Cha = df.groupby(df.City)
df_Cha = df_Cha.get_group('Chandigarh')
df_Cha = fun(df_Cha)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Chennai Imputation

# %%
df_Che = df.groupby(df.City)
df_Che = df_Che.get_group('Chennai')
df_Che = fun(df_Che)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Coimbatore Imputation

# %%
df_Coi = df.groupby(df.City)
df_Coi = df_Coi.get_group('Coimbatore')
df_Coi = fun(df_Coi)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Delhi Imputation

# %%
df_Del = df.groupby(df.City)
df_Del = df_Del.get_group('Delhi')
df_Del = fun(df_Del)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Ernakulam Imputation

# %%
df_Ern = df.groupby(df.City)
df_Ern = df_Ern.get_group('Ernakulam')
df_Ern = fun(df_Ern)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Gurugram Imputation

# %%
df_Gur = df.groupby(df.City)
df_Gur = df_Gur.get_group('Gurugram')
df_Gur = fun(df_Gur)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Guwahati Imputation

# %%
df_Guw = df.groupby(df.City)
df_Guw = df_Guw.get_group('Guwahati')
df_Guw = fun(df_Guw)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Hyderabad Imputation

# %%
df_Hyd = df.groupby(df.City)
df_Hyd = df_Hyd.get_group('Hyderabad')
df_Hyd = fun(df_Hyd)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Jaipur Imputation

# %%
df_Jai = df.groupby(df.City)
df_Jai = df_Jai.get_group('Jaipur')
df_Jai = fun(df_Jai)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Jorapokhar Imputation

# %%
df_Jor = df.groupby(df.City)
df_Jor = df_Jor.get_group('Jorapokhar')
df_Jor = fun(df_Jor)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Kochi Imputation

# %%
df_Koc = df.groupby(df.City)
df_Koc = df_Koc.get_group('Kochi')
df_Koc = fun(df_Koc)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Kolkata Imputation

# %%
df_Kol = df.groupby(df.City)
df_Kol = df_Kol.get_group('Kolkata')
df_Kol = fun(df_Kol)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Lucknow Imputation

# %%
df_Luc = df.groupby(df.City)
df_Luc = df_Luc.get_group('Lucknow')
df_Luc = fun(df_Luc)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Mumbai Imputation

# %%
df_Mum = df.groupby(df.City)
df_Mum = df_Mum.get_group('Mumbai')
df_Mum = fun(df_Mum)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Patna Imputation

# %%
df_Pat = df.groupby(df.City)
df_Pat = df_Pat.get_group('Patna')
df_Pat = fun(df_Pat)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Shillong Imputation

# %%
df_Shi = df.groupby(df.City)
df_Shi = df_Shi.get_group('Shillong')
df_Shi = fun(df_Shi)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Talcher Imputation

# %%
df_Tal = df.groupby(df.City)
df_Tal = df_Tal.get_group('Talcher')
df_Tal = fun(df_Tal)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Thiruvananthapuram Imputation

# %%
df_Thi = df.groupby(df.City)
df_Thi = df_Thi.get_group('Thiruvananthapuram')
df_Thi = fun(df_Thi)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##Visakhapatnam Imputation

# %%
df_Vis = df.groupby(df.City)
df_Vis = df_Vis.get_group('Visakhapatnam')
df_Vis = fun(df_Vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# ##AQI CALCULATION

# %%
print(df['City'].unique())
# Out:
# ['Ahmedabad' 'Aizawl' 'Amaravati' 'Amritsar' 'Bengaluru' 'Bhopal'
#  'Brajrajnagar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Delhi' 'Ernakulam'
#  'Gurugram' 'Guwahati' 'Hyderabad' 'Jaipur' 'Jorapokhar' 'Kochi' 'Kolkata'
#  'Lucknow' 'Mumbai' 'Patna' 'Shillong' 'Talcher' 'Thiruvananthapuram'
#  'Visakhapatnam']

# %%
final_df.to_csv('/content/sample_data/final_imputation_new.csv')

# %%
df = pd.read_csv('/content/Shubham imputed_cities_by_day.csv')
df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5          223
# PM10           230
# NO             220
# NO2            242
# NOx             32
# NH3            207
# CO              33
# SO2            221
# O3             223
# C6H6            32
# C7H8            32
# C8H10         1201
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %%
df
# Out:
#                 City        Date   PM2.5  ...  C8H10   AQI    AQI_Bucket
# 0          Ahmedabad  01-01-2015    0.00  ...   0.00   NaN           NaN
# 1          Ahmedabad  01-02-2015   66.00  ...   3.77   NaN           NaN
# 2          Ahmedabad  01-03-2015  132.00  ...   2.25   NaN           NaN
# 3          Ahmedabad  01-04-2015  150.00  ...   1.00   NaN           NaN
# 4          Ahmedabad  01-05-2015  156.00  ...   2.78   NaN           NaN
# ...              ...         ...     ...  ...    ...   ...           ...
# 29526  Visakhapatnam   6/27/2020   15.02  ...   0.73  41.0          Good
# 29527  Visakhapatnam   6/28/2020   24.38  ...   0.38  70.0  Satisfactory
# 29528  Visakhapatnam   6/29/2020   22.91  ...   0.00  68.0  Satisfactory
# 29529  Visakhapatnam   6/30/2020   16.64  ...   0.00  54.0  Satisfactory
# 29530  Visakhapatnam  07-01-2020   15.00  ...    NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
def aqi_calc(df):
  df["PM10_24hr_avg"] = df.groupby("City")["PM10"].rolling(window = 24, min_periods = 16).mean().values
  df["PM2.5_24hr_avg"] = df.groupby("City")["PM2.5"].rolling(window = 24, min_periods = 16).mean().values
  df["SO2_24hr_avg"] = df.groupby("City")["SO2"].rolling(window = 24, min_periods = 16).mean().values
  df["NOx_24hr_avg"] = df.groupby("City")["NOx"].rolling(window = 24, min_periods = 16).mean().values
  df["NH3_24hr_avg"] = df.groupby("City")["NH3"].rolling(window = 24, min_periods = 16).mean().values
  df["CO_8hr_max"] = df.groupby("City")["CO"].rolling(window = 8, min_periods = 1).max().values
  df["O3_8hr_max"] = df.groupby("City")["O3"].rolling(window = 8, min_periods = 1).max().values

  def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

  df["PM2.5_SubIndex"] = df["PM2.5_24hr_avg"].apply(lambda x: get_PM25_subindex(x))

  def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x <= 100:
        return x
    elif x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x <= 350:
        return 200 + (x - 250)
    elif x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0

  df["PM10_SubIndex"] = df["PM10_24hr_avg"].apply(lambda x: get_PM10_subindex(x))

  def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

  df["SO2_SubIndex"] = df["SO2_24hr_avg"].apply(lambda x: get_SO2_subindex(x))

  def get_NOx_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

  df["NOx_SubIndex"] = df["NOx_24hr_avg"].apply(lambda x: get_NOx_subindex(x))

  def get_NH3_subindex(x):
    if x <= 200:
        return x * 50 / 200
    elif x <= 400:
        return 50 + (x - 200) * 50 / 200
    elif x <= 800:
        return 100 + (x - 400) * 100 / 400
    elif x <= 1200:
        return 200 + (x - 800) * 100 / 400
    elif x <= 1800:
        return 300 + (x - 1200) * 100 / 600
    elif x > 1800:
        return 400 + (x - 1800) * 100 / 600
    else:
        return 0

  df["NH3_SubIndex"] = df["NH3_24hr_avg"].apply(lambda x: get_NH3_subindex(x))

  def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

  df["CO_SubIndex"] = df["CO_8hr_max"].apply(lambda x: get_CO_subindex(x))

  def get_O3_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

  df["O3_SubIndex"] = df["O3_8hr_max"].apply(lambda x: get_O3_subindex(x))
  

  def get_AQI_bucket(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN

  df["Checks"] = (df["PM2.5_SubIndex"] > 0).astype(int) + \
                (df["PM10_SubIndex"] > 0).astype(int) + \
                (df["SO2_SubIndex"] > 0).astype(int) + \
                (df["NOx_SubIndex"] > 0).astype(int) + \
                (df["NH3_SubIndex"] > 0).astype(int) + \
                (df["CO_SubIndex"] > 0).astype(int) + \
                (df["O3_SubIndex"] > 0).astype(int)

  df["AQI_calculated"] = round(df[["PM2.5_SubIndex", "PM10_SubIndex", "SO2_SubIndex", "NOx_SubIndex",
                                 "NH3_SubIndex", "CO_SubIndex", "O3_SubIndex"]].max(axis = 1))
  df.loc[df["PM2.5_SubIndex"] + df["PM10_SubIndex"] <= 0, "AQI_calculated"] = np.NaN
  df.loc[df.Checks < 3, "AQI_calculated"] = np.NaN

  df["AQI_bucket_calculated"] = df["AQI_calculated"].apply(lambda x: get_AQI_bucket(x))
  df[~df.AQI_calculated.isna()].head(13)

aqi_calc(df)
df.to_csv('/content/sample_data/AQI_Calculated_imputation.csv')

# %% [markdown]
# ##Outlier Detection & Treatment

# %%
import pandas as pd
import numpy as np
import os
df = pd.read_csv('/content/sample_data/AQI_Calculated_imputation.csv')
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# City                        0
# Date                        0
# PM2.5                     223
# PM10                      230
# NO                        220
# NO2                       242
# NOx                        32
# NH3                       207
# CO                         33
# SO2                       221
# O3                        223
# C6H6                       32
# C7H8                       32
# C8H10                    1201
# AQI                      4681
# AQI_Bucket               4681
# PM10_24hr_avg             629
# PM2.5_24hr_avg            612
# SO2_24hr_avg              611
# NOx_24hr_avg              408
# NH3_24hr_avg              592
# CO_8hr_max                  2
# O3_8hr_max                171
# PM2.5_SubIndex              0
# PM10_SubIndex               0
# SO2_SubIndex                0
# NOx_SubIndex                0
# NH3_SubIndex                0
# CO_SubIndex                 0
# O3_SubIndex                 0
# ...

# %%
import seaborn as sns
sns.boxplot(data=df,x=df['AQI_calculated'])

# %%
Q1=df['AQI_calculated'].quantile(0.25)
Q3=df['AQI_calculated'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)
Lower_Whisker = Q1 - 1.5*IQR
Upper_Whisker = Q3 + 1.5*IQR
print(Lower_Whisker, Upper_Whisker)
df = df[df['AQI_calculated']< Upper_Whisker]
# Out:
# 491.0
# 1130.0
# 639.0
# -467.5 2088.5

# %%
sns.boxplot(data=df,x=df['AQI_calculated'])

# %%
df.to_csv('/content/sample_data/city_by_day_outlier_treatment.csv')
